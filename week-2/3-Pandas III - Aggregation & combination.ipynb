# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Data-aggregation" data-toc-modified-id="Data-aggregation-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Data aggregation</a></span><ul class="toc-item"><li><span><a href="#groupby" data-toc-modified-id="groupby-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>groupby</a></span><ul class="toc-item"><li><span><a href="#groupby-&amp;-aggregate" data-toc-modified-id="groupby-&amp;-aggregate-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>groupby &amp; aggregate</a></span></li></ul></li><li><span><a href="#Pivot-Tables" data-toc-modified-id="Pivot-Tables-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Pivot Tables</a></span></li><li><span><a href="#Differences-between-pivot-table-and-groupby-function" data-toc-modified-id="Differences-between-pivot-table-and-groupby-function-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Differences between pivot table and groupby function</a></span></li><li><span><a href="#crosstab" data-toc-modified-id="crosstab-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>crosstab</a></span></li></ul></li><li><span><a href="#Data-combination:-mixing-dataframes" data-toc-modified-id="Data-combination:-mixing-dataframes-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Data combination: mixing dataframes</a></span><ul class="toc-item"><li><span><a href="#Concat:-two-things-together" data-toc-modified-id="Concat:-two-things-together-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Concat: two things together</a></span><ul class="toc-item"><li><span><a href="#Concatenating-on-axis-0-(rows)" data-toc-modified-id="Concatenating-on-axis-0-(rows)-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Concatenating on axis 0 (rows)</a></span></li><li><span><a href="#Concatenating-on-axis-1-(columns)" data-toc-modified-id="Concatenating-on-axis-1-(columns)-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>Concatenating on axis 1 (columns)</a></span></li></ul></li><li><span><a href="#Merge:-related-columns" data-toc-modified-id="Merge:-related-columns-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Merge: related columns</a></span><ul class="toc-item"><li><span><a href="#LEFT-Merge" data-toc-modified-id="LEFT-Merge-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>LEFT Merge</a></span></li><li><span><a href="#RIGHT-Merge" data-toc-modified-id="RIGHT-Merge-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>RIGHT Merge</a></span></li><li><span><a href="#INNER-Merge" data-toc-modified-id="INNER-Merge-2.2.3"><span class="toc-item-num">2.2.3&nbsp;&nbsp;</span>INNER Merge</a></span></li><li><span><a href="#OUTER-Merge" data-toc-modified-id="OUTER-Merge-2.2.4"><span class="toc-item-num">2.2.4&nbsp;&nbsp;</span>OUTER Merge</a></span></li></ul></li><li><span><a href="#Merging-&amp;-Concatenating-in-two-different-columns" data-toc-modified-id="Merging-&amp;-Concatenating-in-two-different-columns-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Merging &amp; Concatenating in two different columns</a></span><ul class="toc-item"><li><span><a href="#Concatenating-in-two-different-columns" data-toc-modified-id="Concatenating-in-two-different-columns-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Concatenating in two different columns</a></span></li><li><span><a href="#Merging-in-two-different-columns" data-toc-modified-id="Merging-in-two-different-columns-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>Merging in two different columns</a></span></li></ul></li><li><span><a href="#Join:-relating-index" data-toc-modified-id="Join:-relating-index-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Join: relating index</a></span></li><li><span><a href="#Differences-between-join-&amp;-merge" data-toc-modified-id="Differences-between-join-&amp;-merge-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Differences between join &amp; merge</a></span></li></ul></li><li><span><a href="#Pandas-usual-methods" data-toc-modified-id="Pandas-usual-methods-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Pandas usual methods</a></span></li><li><span><a href="#Further-materials" data-toc-modified-id="Further-materials-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Further materials</a></span></li></ul></div>

# %% [markdown]
# ![](https://miro.medium.com/max/1400/1*6d5dw6dPhy4vBp2vRW6uzw.webp)

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../datasets/employees.csv")

# %%
df.sample()
# Out:
#      Age Attrition BusinessTravel  DailyRate Department  DistanceFromHome
# 638   25        No  Travel_Rarely        583      Sales                 4  \
#
#      Education EducationField  EmployeeCount  EmployeeNumber  ...
# 638          1      Marketing              1             885  ...  \
#
#      RelationshipSatisfaction StandardHours  StockOptionLevel
# 638                         1            80                 0  \
#
#      TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany
# 638                  5                      1               4               5  \
#
#     YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 638                  2                        0                     3
#
# [1 rows x 35 columns]

# %% [markdown]
# ## Data aggregation

# %% [markdown]
# `groupby, pivot table & cross_tab`

# %% [markdown]
# ### groupby
# Pandas GroupBy is a powerful and versatile function in Python. It allows us to split your data into separate groups to perform calculations for better analysis.
# A DataFrame can be grouped on its rows (axis=0) or on its columns (axis=1). Once this is done, a function is applied to each group, producing a new value. Finally, the results of all those function applications are combined into a result object. The shape of the resulting object will usually depend on what is done with the data.

# %% [markdown]
# `df[subset].groupby(category).aggregation()`

# %% [markdown]
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.groupby.html

# %%
#df.groupby().aggregate()
#df.groupby("type")[["averageprice"]].mean()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department
# 0      41       Yes      Travel_Rarely       1102                   Sales  \
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount
# 0                    1          2  Life Sciences              1  \
# 1                    8          1  Life Sciences              1
# 2                    2          2          Other              1
# 3                    3          4  Life Sciences              1
# 4                    2          1        Medical              1
# ...                ...        ...            ...            ...
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours
# 0                  1  ...                         1            80  \
# 1                  2  ...                         4            80
# 2                  4  ...                         2            80
# 3                  5  ...                         3            80
# 4                  7  ...                         4            80
# ...              ...  ...                       ...           ...
# 1465            2061  ...                         3            80
# 1466            2062  ...                         1            80
# 1467            2064  ...                         2            80
# 1468            2065  ...                         4            80
# 1469            2068  ...                         1            80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear
# 0                    0                  8                      0  \
# 1                    1                 10                      3
# 2                    0                  7                      3
# 3                    0                  8                      3
# 4                    1                  6                      3
# ...                ...                ...                    ...
# 1465                 1                 17                      3
# 1466                 1                  9                      5
# 1467                 1                  6                      0
# 1468                 0                 17                      3
# 1469                 0                  6                      3
#
#      WorkLifeBalance  YearsAtCompany YearsInCurrentRole
# 0                  1               6                  4  \
# 1                  3              10                  7
# 2                  3               0                  0
# 3                  3               8                  7
# 4                  3               2                  2
# ...              ...             ...                ...
# 1465               3               5                  2
# 1466               3               7                  7
# 1467               3               6                  2
# 1468               2               9                  6
# 1469               4               4                  3
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 0                           0                     5
# 1                           1                     7
# 2                           0                     0
# 3                           3                     0
# 4                           2                     2
# ...                       ...                   ...
# 1465                        0                     3
# 1466                        1                     7
# 1467                        0                     3
# 1468                        0                     8
# 1469                        1                     2
#
# [1470 rows x 35 columns]

# %% [markdown]
# `groupby the departments and their mean age`

# %%
df[["Age", "Department"]].groupby("Department").mean()
# Out:
#                               Age
# Department
# Human Resources         37.809524
# Research & Development  37.042664
# Sales                   36.542601

# %%
df[["Age", "Department"]].groupby("Department").agg("mean")
# Out:
#                               Age
# Department
# Human Resources         37.809524
# Research & Development  37.042664
# Sales                   36.542601

# %%
df[["Age", "Department"]].groupby("Department").agg({"Age":"count"})
# Out:
#                         Age
# Department
# Human Resources          63
# Research & Development  961
# Sales                   446

# %% [markdown]
# `groupby the departments and their maximum age`

# %%
df[["Age", "Department"]].groupby("Department").agg({"Age":"max"})
# Out:
#                         Age
# Department
# Human Resources          59
# Research & Development   60
# Sales                    60

# %% [markdown]
# `groupby the departments and their min age`

# %% [markdown]
# `groupby: 2+`: Different Education Fields and their Mean Salaries in each of the Department

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
"$" + " " + str(df[["EducationField", "HourlyRate", "Department"]].loc[0]["HourlyRate"] * 8 * 5 * 4)
# Out:
# '$ 15040'

# %%
df[["EducationField", "HourlyRate", "Department"]]
# Out:
#      EducationField  HourlyRate              Department
# 0     Life Sciences          94                   Sales
# 1     Life Sciences          61  Research & Development
# 2             Other          92  Research & Development
# 3     Life Sciences          56  Research & Development
# 4           Medical          40  Research & Development
# ...             ...         ...                     ...
# 1465        Medical          41  Research & Development
# 1466        Medical          42  Research & Development
# 1467  Life Sciences          87  Research & Development
# 1468        Medical          63                   Sales
# 1469        Medical          82  Research & Development
#
# [1470 rows x 3 columns]

# %%
df[["EducationField", "HourlyRate", "Department"]].groupby(by=["Department", "EducationField"]).agg({"HourlyRate":"mean"})
# Out:
#                                          HourlyRate
# Department             EducationField
# Human Resources        Human Resources    60.888889
#                        Life Sciences      61.625000
#                        Medical            72.076923
#                        Other              76.000000
#                        Technical Degree   64.000000
# Research & Development Life Sciences      66.570455
#                        Medical            66.330579
#                        Other              62.203125
#                        Technical Degree   66.351064
# Sales                  Life Sciences      68.153333
#                        Marketing          66.150943
#                        Medical            59.943182
#                        Other              60.333333
#                        Technical Degree   67.676471

# %%
df[["EducationField", "HourlyRate", "Department"]].groupby(by=["EducationField", "Department"]).agg({"HourlyRate":"mean"})
# Out:
#                                          HourlyRate
# EducationField   Department
# Human Resources  Human Resources          60.888889
# Life Sciences    Human Resources          61.625000
#                  Research & Development   66.570455
#                  Sales                    68.153333
# Marketing        Sales                    66.150943
# Medical          Human Resources          72.076923
#                  Research & Development   66.330579
#                  Sales                    59.943182
# Other            Human Resources          76.000000
#                  Research & Development   62.203125
#                  Sales                    60.333333
# Technical Degree Human Resources          64.000000
#                  Research & Development   66.351064
#                  Sales                    67.676471

# %%
# multiindex: https://pandas.pydata.org/docs/user_guide/advanced.html

# %% [markdown]
# `more fields`

# %%
df[["EducationField", "HourlyRate", "Department", "StandardHours", "Age"]].groupby(by=["Department", "EducationField"]).mean()
# Out:
#                                          HourlyRate  StandardHours        Age
# Department             EducationField
# Human Resources        Human Resources    60.888889           80.0  37.037037
#                        Life Sciences      61.625000           80.0  39.375000
#                        Medical            72.076923           80.0  39.846154
#                        Other              76.000000           80.0  34.666667
#                        Technical Degree   64.000000           80.0  32.500000
# Research & Development Life Sciences      66.570455           80.0  36.997727
#                        Medical            66.330579           80.0  37.242424
#                        Other              62.203125           80.0  36.187500
#                        Technical Degree   66.351064           80.0  37.063830
# Sales                  Life Sciences      68.153333           80.0  37.186667
#                        Marketing          66.150943           80.0  37.924528
#                        Medical            59.943182           80.0  34.727273
#                        Other              60.333333           80.0  32.000000
#                        Technical Degree   67.676471           80.0  33.941176

# %% [markdown]
# #### groupby & aggregate

# %% [markdown]
# Another way to groupby with agg syntax
# https://pandas.pydata.org/docs/reference/api/pandas.core.groupby.DataFrameGroupBy.aggregate.html
#
# - mean
# - sum
# -count

# %% [markdown]
# Suppose we want to calculate the mean of column data1 using the labels of key1. There are several ways to do it. One is to access data1 and call groupby with the column (a String) in key1.
# The data (a Series) has been aggregated based on the group key, producing a new String that is now indexed by the unique values ​​of the key1 column. The resulting index has the name 'key1' because the DataFrame column `df['key1']` did.

# %% [markdown]
# ### Pivot Tables

# %% [markdown]
# [groupby vs pivot table](https://towardsdatascience.com/a-comparison-of-groupby-and-pivot-in-pythons-pandas-module-527909e78d6b?source=userActivityShare-4c6d9a33c6-1674605913&_branch_match_id=1146490620103499300&_branch_referrer=H4sIAAAAAAAAA8soKSkottLXz8nMy9bLTU3JLM3VS87P1TfKCvCtKvOvCCpPAgAN4ht%2FIwAAAA%3D%3D)

# %% [markdown]
# ```pivot_table(df, values=None, index=None, columns=None, aggfunc='mean', ...)```

# %% [markdown]
# * We can create a spreadsheet-style pivot table as a DataFrame. The levels in the pivot table will be stored in MultiIndex objects (hierarchical indexes) on the index and columns of the result DataFrame.

# %% [markdown]
# `pivot table`: the department and their mean ages

# %%
# 1. Age
# 2. Department

# 3. Mean

df.pivot_table(
    values = "Age",
    index = "Department",
    aggfunc = "mean"
)
# Out:
#                               Age
# Department
# Human Resources         37.809524
# Research & Development  37.042664
# Sales                   36.542601

# %% [markdown]
# `pivot table`: the department and their max ages

# %% [markdown]
# `pivot table`: the department and their min ages

# %% [markdown]
# `pivot table`: the department and their median age

# %% [markdown]
# `multi-index pivot table`: Department and Education Field and check the maximum salary values of employees

# %%
# 1. Salaries
# 2. Department & EducationField

# 3. Max

df.pivot_table (
    values = "MonthlyIncome",
    index = ["Department", "EducationField"],
    aggfunc = "max"
)
# Out:
#                                          MonthlyIncome
# Department             EducationField
# Human Resources        Human Resources           19636
#                        Life Sciences             19717
#                        Medical                   18200
#                        Other                      7988
#                        Technical Degree           4323
# Research & Development Life Sciences             19999
#                        Medical                   19859
#                        Other                     19613
#                        Technical Degree          19943
# Sales                  Life Sciences             19847
#                        Marketing                 19845
#                        Medical                   19833
#                        Other                     10932
#                        Technical Degree          16872

# %% [markdown]
# ### Differences between pivot table and groupby function

# %% [markdown]
# `groupby`: team mean age by team abbreviation & season.

# %% [markdown]
# `pivot_table`: team mean age by team abbreviation & season.

# %% [markdown]
# ### crosstab

# %% [markdown]
# * Compute a simple cross tabulation of two (or more) factors. By default computes a frequency table of the factors unless an array of values and an aggregation function are passed. Usually used to see the frequency of two qualitative variables: how many times the value of one column happens in the other one

# %% [markdown]
# ```pd.crosstab(df[column1], df[column2])```

# %%
pd.crosstab(df["Department"], df["EducationField"])
# Out:
# EducationField          Human Resources  Life Sciences  Marketing  Medical
# Department
# Human Resources                      27             16          0       13  \
# Research & Development                0            440          0      363
# Sales                                 0            150        159       88
#
# EducationField          Other  Technical Degree
# Department
# Human Resources             3                 4
# Research & Development     64                94
# Sales                      15                34

# %%
pd.crosstab(df["Department"], df["EducationField"], df["MonthlyIncome"], aggfunc="mean")
# Out:
# EducationField          Human Resources  Life Sciences    Marketing
# Department
# Human Resources             7241.148148    6914.062500          NaN  \
# Research & Development              NaN    6179.984091          NaN
# Sales                               NaN    7246.233333  7348.584906
#
# EducationField              Medical        Other  Technical Degree
# Department
# Human Resources         6594.076923  5016.666667       3081.250000
# Research & Development  6539.223140  6278.687500       5760.819149
# Sales                   6377.227273  5398.733333       6066.294118

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Data combination: mixing dataframes

# %% [markdown]
# - https://realpython.com/pandas-merge-join-and-concat/
# - https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html

# %% [markdown]
# ### Concat: two things together
# We join dataframes along axis 0 one below the other. Align columns by label.

# %%
df = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user',
                             sep='|', 
                             index_col='user_id')
df.sample()
# Out:
#          age gender occupation zip_code
# user_id
# 531       30      F   salesman    97408

# %%
df.shape
# Out:
# (943, 4)

# %%
first_df = df.sample(frac=0.1)
second_df = df.sample(frac=0.1)

# %%
first_df.shape
# Out:
# (94, 4)

# %%
first_df
# Out:
#          age gender     occupation zip_code
# user_id
# 72        48      F  administrator    73034
# 691       34      M       educator    60089
# 479       30      M       educator    55409
# 725       21      M        student    91711
# 145       31      M  entertainment    V3N4P
# ...      ...    ...            ...      ...
# 140       30      F        student    32250
# 15        49      F       educator    97301
# 456       24      M     technician    31820
# 268       24      M       engineer    19422
# 248       25      M        student    37235
#
# [94 rows x 4 columns]

# %%
second_df
# Out:
#          age gender     occupation zip_code
# user_id
# 452       35      M  administrator    28018
# 245       22      M        student    55109
# 167       37      M          other    L9G2B
# 227       46      M      executive    60659
# 581       37      M          other    94131
# ...      ...    ...            ...      ...
# 674       13      F        student    55337
# 745       42      M         writer    55113
# 709       21      M          other    N4T1A
# 449       23      M      librarian    55021
# 159       23      F        student    55346
#
# [94 rows x 4 columns]

# %%
second_df.shape
# Out:
# (94, 4)

# %% [markdown]
# #### Concatenating on axis 0 (rows)

# %%
concatenated_rows = pd.concat([first_df, second_df], axis=0, keys=["Table 1", "Table 2"])
concatenated_rows
# Out:
#                  age gender     occupation zip_code
#         user_id
# Table 1 72        48      F  administrator    73034
#         691       34      M       educator    60089
#         479       30      M       educator    55409
#         725       21      M        student    91711
#         145       31      M  entertainment    V3N4P
# ...              ...    ...            ...      ...
# Table 2 674       13      F        student    55337
#         745       42      M         writer    55113
#         709       21      M          other    N4T1A
#         449       23      M      librarian    55021
#         159       23      F        student    55346
#
# [188 rows x 4 columns]

# %% [markdown]
# #### Concatenating on axis 1 (columns)

# %%
pd.concat([first_df, second_df], axis=1, keys=["left", "right"])
# Out:
#          left                                right
#           age gender     occupation zip_code   age gender     occupation
# user_id
# 72       48.0      F  administrator    73034  48.0      F  administrator  \
# 691      34.0      M       educator    60089  34.0      M       educator
# 479      30.0      M       educator    55409   NaN    NaN            NaN
# 725      21.0      M        student    91711   NaN    NaN            NaN
# 145      31.0      M  entertainment    V3N4P   NaN    NaN            NaN
# ...       ...    ...            ...      ...   ...    ...            ...
# 393       NaN    NaN            NaN      NaN  19.0      M        student
# 674       NaN    NaN            NaN      NaN  13.0      F        student
# 709       NaN    NaN            NaN      NaN  21.0      M          other
# 449       NaN    NaN            NaN      NaN  23.0      M      librarian
# 159       NaN    NaN            NaN      NaN  23.0      F        student
#
#
#         zip_code
# user_id
# 72         73034
# 691        60089
# 479          NaN
# 725          NaN
# 145          NaN
# ...          ...
# 393        83686
# 674        55337
# 709        N4T1A
# 449        55021
# 159        55346
#
# [177 rows x 8 columns]

# %% [markdown]
# ![sql joins](https://upload.wikimedia.org/wikipedia/commons/9/9d/SQL_Joins.svg)

# %% [markdown]
# ### Merge: related columns

# %% [markdown]
# [Merge()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.merge.html) is most useful when you want to merge rows that share data.

# %%
from IPython.display import display_html

# %%
df1 = pd.DataFrame(
    {
        "key1": ["K0", "K0", "K1", "K2"],
        "key2": ["K0", "K1", "K0", "K1"],
        "A": ["A0", "A1", "A2", "A3"],
        "B": ["B0", "B1", "B2", "B3"],
    }
)


df2 = pd.DataFrame(
    {
        "key1": ["K0", "K1", "K1", "K2"],
        "key2": ["K0", "K0", "K0", "K0"],
        "C": ["C0", "C1", "C2", "C3"],
        "D": ["D0", "D1", "D2", "D3"],
    }
)

df3 = pd.DataFrame(
    {
        "key1": ["K90", "K1", "K1", "K2"],
        "key2": ["K0", "K0", "K5", "K0"],
        "C": ["C0", "C1", "C2", "C3"],
        "Y": ["D0", "D70", "D2", "D5"],
    }
)

# %%
df1_styler = df1.style.set_table_attributes("style='display:inline'").set_caption('Left table')
df2_styler = df2.style.set_table_attributes("style='display:inline'").set_caption('Right table')
display_html(df1_styler._repr_html_() + " " + df2_styler._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_e34ad" style='display:inline'>
#   <caption>Left table</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e34ad_level0_col0" class="col_heading level0 col0" >key1</th>
#       <th id="T_e34ad_level0_col1" class="col_heading level0 col1" >key2</th>
#       <th id="T_e34ad_level0_col2" class="col_heading level0 col2" >A</th>
#       <th id="T_e34ad_level0_col3" class="col_heading level0 col3" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e34ad_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e34ad_row0_col0" class="data row0 col0" >K0</td>
#       <td id="T_e34ad_row0_col1" class="data row0 col1" >K0</td>
#       <td id="T_e34ad_row0_col2" class="data row0 col2" >A0</td>
#       <td id="T_e34ad_row0_col3" class="data row0 col3" >B0</td>
#     </tr>
#     <tr>
#       <th id="T_e34ad_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e34ad_row1_col0" class="data row1 col0" >K0</td>
#       <td id="T_e34ad_row1_col1" class="data row1 col1" >K1</td>
#       <td id="T_e34ad_row1_col2" class="data row1 col2" >A1</td>
#       <td id="T_e34ad_row1_col3" class="data row1 col3" >B1</td>
#     </tr>
#     <tr>
#       <th id="T_e34ad_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e34ad_row2_col0" class="data row2 col0" >K1</td>
#       <td id="T_e34ad_row2_col1" class="data row2 col1" >K0</td>
#       <td id="T_e34ad_row2_col2" class="data row2 col2" >A2</td>
#       <td id="T_e34ad_row2_col3" class="data row2 col3" >B2</td>
#     </tr>
#     <tr>
#       <th id="T_e34ad_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e34ad_row3_col0" class="data row3 col0" >K2</td>
#       <td id="T_e34ad_row3_col1" class="data row3 col1" >K1</td>
#       <td id="T_e34ad_row3_col2" class="data row3 col2" >A3</td>
#       <td id="T_e34ad_row3_col3" class="data row3 col3" >B3</td>
#     </tr>
#   </tbody>
# </table>
#  <style type="text/css">
# </style>
# <table id="T_239c1" style='display:inline'>
#   <caption>Right table</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_239c1_level0_col0" class="col_heading level0 col0" >key1</th>
#       <th id="T_239c1_level0_col1" class="col_heading level0 col1" >key2</th>
#       <th id="T_239c1_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_239c1_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_239c1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_239c1_row0_col0" class="data row0 col0" >K0</td>
#       <td id="T_239c1_row0_col1" class="data row0 col1" >K0</td>
#       <td id="T_239c1_row0_col2" class="data row0 col2" >C0</td>
#       <td id="T_239c1_row0_col3" class="data row0 col3" >D0</td>
#     </tr>
#     <tr>
#       <th id="T_239c1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_239c1_row1_col0" class="data row1 col0" >K1</td>
#       <td id="T_239c1_row1_col1" class="data row1 col1" >K0</td>
#       <td id="T_239c1_row1_col2" class="data row1 col2" >C1</td>
#       <td id="T_239c1_row1_col3" class="data row1 col3" >D1</td>
#     </tr>
#     <tr>
#       <th id="T_239c1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_239c1_row2_col0" class="data row2 col0" >K1</td>
#       <td id="T_239c1_row2_col1" class="data row2 col1" >K0</td>
#       <td id="T_239c1_row2_col2" class="data row2 col2" >C2</td>
#       <td id="T_239c1_row2_col3" class="data row2 col3" >D2</td>
#     </tr>
#     <tr>
#       <th id="T_239c1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_239c1_row3_col0" class="data row3 col0" >K2</td>
#       <td id="T_239c1_row3_col1" class="data row3 col1" >K0</td>
#       <td id="T_239c1_row3_col2" class="data row3 col2" >C3</td>
#       <td id="T_239c1_row3_col3" class="data row3 col3" >D3</td>
#     </tr>
#   </tbody>
# </table>

# %%
# merge, default is inner

result = pd.merge(df1, df2)
result
# Out:
#   key1 key2   A   B   C   D
# 0   K0   K0  A0  B0  C0  D0
# 1   K1   K0  A2  B2  C1  D1
# 2   K1   K0  A2  B2  C2  D2

# %% [markdown]
# #### LEFT Merge

# %%
left_merge = pd.merge(df1, df2, how="left")


df1_styler = df1.style.set_table_attributes("style='display:inline'").set_caption('Left table')
df2_styler = df2.style.set_table_attributes("style='display:inline'").set_caption('Right table')
left_merge = left_merge.style.set_table_attributes("style='display:inline'").set_caption("left_merge")

display_html(df1_styler._repr_html_() +  " " + df2_styler._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_f36c4" style='display:inline'>
#   <caption>Left table</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f36c4_level0_col0" class="col_heading level0 col0" >key1</th>
#       <th id="T_f36c4_level0_col1" class="col_heading level0 col1" >key2</th>
#       <th id="T_f36c4_level0_col2" class="col_heading level0 col2" >A</th>
#       <th id="T_f36c4_level0_col3" class="col_heading level0 col3" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f36c4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f36c4_row0_col0" class="data row0 col0" >K0</td>
#       <td id="T_f36c4_row0_col1" class="data row0 col1" >K0</td>
#       <td id="T_f36c4_row0_col2" class="data row0 col2" >A0</td>
#       <td id="T_f36c4_row0_col3" class="data row0 col3" >B0</td>
#     </tr>
#     <tr>
#       <th id="T_f36c4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f36c4_row1_col0" class="data row1 col0" >K0</td>
#       <td id="T_f36c4_row1_col1" class="data row1 col1" >K1</td>
#       <td id="T_f36c4_row1_col2" class="data row1 col2" >A1</td>
#       <td id="T_f36c4_row1_col3" class="data row1 col3" >B1</td>
#     </tr>
#     <tr>
#       <th id="T_f36c4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f36c4_row2_col0" class="data row2 col0" >K1</td>
#       <td id="T_f36c4_row2_col1" class="data row2 col1" >K0</td>
#       <td id="T_f36c4_row2_col2" class="data row2 col2" >A2</td>
#       <td id="T_f36c4_row2_col3" class="data row2 col3" >B2</td>
#     </tr>
#     <tr>
#       <th id="T_f36c4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f36c4_row3_col0" class="data row3 col0" >K2</td>
#       <td id="T_f36c4_row3_col1" class="data row3 col1" >K1</td>
#       <td id="T_f36c4_row3_col2" class="data row3 col2" >A3</td>
#       <td id="T_f36c4_row3_col3" class="data row3 col3" >B3</td>
#     </tr>
#   </tbody>
# </table>
#  <style type="text/css">
# </style>
# <table id="T_54267" style='display:inline'>
#   <caption>Right table</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_54267_level0_col0" class="col_heading level0 col0" >key1</th>
#       <th id="T_54267_level0_col1" class="col_heading level0 col1" >key2</th>
#       <th id="T_54267_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_54267_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_54267_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_54267_row0_col0" class="data row0 col0" >K0</td>
#       <td id="T_54267_row0_col1" class="data row0 col1" >K0</td>
#       <td id="T_54267_row0_col2" class="data row0 col2" >C0</td>
#       <td id="T_54267_row0_col3" class="data row0 col3" >D0</td>
#     </tr>
#     <tr>
#       <th id="T_54267_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_54267_row1_col0" class="data row1 col0" >K1</td>
#       <td id="T_54267_row1_col1" class="data row1 col1" >K0</td>
#       <td id="T_54267_row1_col2" class="data row1 col2" >C1</td>
#       <td id="T_54267_row1_col3" class="data row1 col3" >D1</td>
#     </tr>
#     <tr>
#       <th id="T_54267_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_54267_row2_col0" class="data row2 col0" >K1</td>
#       <td id="T_54267_row2_col1" class="data row2 col1" >K0</td>
#       <td id="T_54267_row2_col2" class="data row2 col2" >C2</td>
#       <td id="T_54267_row2_col3" class="data row2 col3" >D2</td>
#     </tr>
#     <tr>
#       <th id="T_54267_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_54267_row3_col0" class="data row3 col0" >K2</td>
#       <td id="T_54267_row3_col1" class="data row3 col1" >K0</td>
#       <td id="T_54267_row3_col2" class="data row3 col2" >C3</td>
#       <td id="T_54267_row3_col3" class="data row3 col3" >D3</td>
#     </tr>
#   </tbody>
# </table>

# %%
display_html(left_merge._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_51bef" style='display:inline'>
#   <caption>left_merge</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_51bef_level0_col0" class="col_heading level0 col0" >key1</th>
#       <th id="T_51bef_level0_col1" class="col_heading level0 col1" >key2</th>
#       <th id="T_51bef_level0_col2" class="col_heading level0 col2" >A</th>
#       <th id="T_51bef_level0_col3" class="col_heading level0 col3" >B</th>
#       <th id="T_51bef_level0_col4" class="col_heading level0 col4" >C</th>
#       <th id="T_51bef_level0_col5" class="col_heading level0 col5" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_51bef_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_51bef_row0_col0" class="data row0 col0" >K0</td>
#       <td id="T_51bef_row0_col1" class="data row0 col1" >K0</td>
#       <td id="T_51bef_row0_col2" class="data row0 col2" >A0</td>
#       <td id="T_51bef_row0_col3" class="data row0 col3" >B0</td>
#       <td id="T_51bef_row0_col4" class="data row0 col4" >C0</td>
#       <td id="T_51bef_row0_col5" class="data row0 col5" >D0</td>
#     </tr>
#     <tr>
#       <th id="T_51bef_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_51bef_row1_col0" class="data row1 col0" >K0</td>
#       <td id="T_51bef_row1_col1" class="data row1 col1" >K1</td>
#       <td id="T_51bef_row1_col2" class="data row1 col2" >A1</td>
#       <td id="T_51bef_row1_col3" class="data row1 col3" >B1</td>
#       <td id="T_51bef_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_51bef_row1_col5" class="data row1 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_51bef_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_51bef_row2_col0" class="data row2 col0" >K1</td>
#       <td id="T_51bef_row2_col1" class="data row2 col1" >K0</td>
#       <td id="T_51bef_row2_col2" class="data row2 col2" >A2</td>
#       <td id="T_51bef_row2_col3" class="data row2 col3" >B2</td>
#       <td id="T_51bef_row2_col4" class="data row2 col4" >C1</td>
#       <td id="T_51bef_row2_col5" class="data row2 col5" >D1</td>
#     </tr>
#     <tr>
#       <th id="T_51bef_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_51bef_row3_col0" class="data row3 col0" >K1</td>
#       <td id="T_51bef_row3_col1" class="data row3 col1" >K0</td>
#       <td id="T_51bef_row3_col2" class="data row3 col2" >A2</td>
#       <td id="T_51bef_row3_col3" class="data row3 col3" >B2</td>
#       <td id="T_51bef_row3_col4" class="data row3 col4" >C2</td>
#       <td id="T_51bef_row3_col5" class="data row3 col5" >D2</td>
#     </tr>
#     <tr>
#       <th id="T_51bef_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_51bef_row4_col0" class="data row4 col0" >K2</td>
#       <td id="T_51bef_row4_col1" class="data row4 col1" >K1</td>
#       <td id="T_51bef_row4_col2" class="data row4 col2" >A3</td>
#       <td id="T_51bef_row4_col3" class="data row4 col3" >B3</td>
#       <td id="T_51bef_row4_col4" class="data row4 col4" >nan</td>
#       <td id="T_51bef_row4_col5" class="data row4 col5" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### RIGHT Merge

# %%
right_merge = pd.merge(df1, df2, how="right")


df1_styler = df1.style.set_table_attributes("style='display:inline'").set_caption('Left table')
df2_styler = df2.style.set_table_attributes("style='display:inline'").set_caption('Right table')
right_merge = right_merge.style.set_table_attributes("style='display:inline'").set_caption("right_merge")

display_html(df1_styler._repr_html_() + " " + df2_styler._repr_html_(),raw=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_9c2b8" style='display:inline'>
#   <caption>Left table</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9c2b8_level0_col0" class="col_heading level0 col0" >key1</th>
#       <th id="T_9c2b8_level0_col1" class="col_heading level0 col1" >key2</th>
#       <th id="T_9c2b8_level0_col2" class="col_heading level0 col2" >A</th>
#       <th id="T_9c2b8_level0_col3" class="col_heading level0 col3" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9c2b8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9c2b8_row0_col0" class="data row0 col0" >K0</td>
#       <td id="T_9c2b8_row0_col1" class="data row0 col1" >K0</td>
#       <td id="T_9c2b8_row0_col2" class="data row0 col2" >A0</td>
#       <td id="T_9c2b8_row0_col3" class="data row0 col3" >B0</td>
#     </tr>
#     <tr>
#       <th id="T_9c2b8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9c2b8_row1_col0" class="data row1 col0" >K0</td>
#       <td id="T_9c2b8_row1_col1" class="data row1 col1" >K1</td>
#       <td id="T_9c2b8_row1_col2" class="data row1 col2" >A1</td>
#       <td id="T_9c2b8_row1_col3" class="data row1 col3" >B1</td>
#     </tr>
#     <tr>
#       <th id="T_9c2b8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9c2b8_row2_col0" class="data row2 col0" >K1</td>
#       <td id="T_9c2b8_row2_col1" class="data row2 col1" >K0</td>
#       <td id="T_9c2b8_row2_col2" class="data row2 col2" >A2</td>
#       <td id="T_9c2b8_row2_col3" class="data row2 col3" >B2</td>
#     </tr>
#     <tr>
#       <th id="T_9c2b8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9c2b8_row3_col0" class="data row3 col0" >K2</td>
#       <td id="T_9c2b8_row3_col1" class="data row3 col1" >K1</td>
#       <td id="T_9c2b8_row3_col2" class="data row3 col2" >A3</td>
#       <td id="T_9c2b8_row3_col3" class="data row3 col3" >B3</td>
#     </tr>
#   </tbody>
# </table>
#  <style type="text/css">
# </style>
# <table id="T_2c810" style='display:inline'>
#   <caption>Right table</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2c810_level0_col0" class="col_heading level0 col0" >key1</th>
#       <th id="T_2c810_level0_col1" class="col_heading level0 col1" >key2</th>
#       <th id="T_2c810_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_2c810_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2c810_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2c810_row0_col0" class="data row0 col0" >K0</td>
#       <td id="T_2c810_row0_col1" class="data row0 col1" >K0</td>
#       <td id="T_2c810_row0_col2" class="data row0 col2" >C0</td>
#       <td id="T_2c810_row0_col3" class="data row0 col3" >D0</td>
#     </tr>
#     <tr>
#       <th id="T_2c810_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2c810_row1_col0" class="data row1 col0" >K1</td>
#       <td id="T_2c810_row1_col1" class="data row1 col1" >K0</td>
#       <td id="T_2c810_row1_col2" class="data row1 col2" >C1</td>
#       <td id="T_2c810_row1_col3" class="data row1 col3" >D1</td>
#     </tr>
#     <tr>
#       <th id="T_2c810_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2c810_row2_col0" class="data row2 col0" >K1</td>
#       <td id="T_2c810_row2_col1" class="data row2 col1" >K0</td>
#       <td id="T_2c810_row2_col2" class="data row2 col2" >C2</td>
#       <td id="T_2c810_row2_col3" class="data row2 col3" >D2</td>
#     </tr>
#     <tr>
#       <th id="T_2c810_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2c810_row3_col0" class="data row3 col0" >K2</td>
#       <td id="T_2c810_row3_col1" class="data row3 col1" >K0</td>
#       <td id="T_2c810_row3_col2" class="data row3 col2" >C3</td>
#       <td id="T_2c810_row3_col3" class="data row3 col3" >D3</td>
#     </tr>
#   </tbody>
# </table>

# %%
display_html(right_merge._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_096e0" style='display:inline'>
#   <caption>right_merge</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_096e0_level0_col0" class="col_heading level0 col0" >key1</th>
#       <th id="T_096e0_level0_col1" class="col_heading level0 col1" >key2</th>
#       <th id="T_096e0_level0_col2" class="col_heading level0 col2" >A</th>
#       <th id="T_096e0_level0_col3" class="col_heading level0 col3" >B</th>
#       <th id="T_096e0_level0_col4" class="col_heading level0 col4" >C</th>
#       <th id="T_096e0_level0_col5" class="col_heading level0 col5" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_096e0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_096e0_row0_col0" class="data row0 col0" >K0</td>
#       <td id="T_096e0_row0_col1" class="data row0 col1" >K0</td>
#       <td id="T_096e0_row0_col2" class="data row0 col2" >A0</td>
#       <td id="T_096e0_row0_col3" class="data row0 col3" >B0</td>
#       <td id="T_096e0_row0_col4" class="data row0 col4" >C0</td>
#       <td id="T_096e0_row0_col5" class="data row0 col5" >D0</td>
#     </tr>
#     <tr>
#       <th id="T_096e0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_096e0_row1_col0" class="data row1 col0" >K1</td>
#       <td id="T_096e0_row1_col1" class="data row1 col1" >K0</td>
#       <td id="T_096e0_row1_col2" class="data row1 col2" >A2</td>
#       <td id="T_096e0_row1_col3" class="data row1 col3" >B2</td>
#       <td id="T_096e0_row1_col4" class="data row1 col4" >C1</td>
#       <td id="T_096e0_row1_col5" class="data row1 col5" >D1</td>
#     </tr>
#     <tr>
#       <th id="T_096e0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_096e0_row2_col0" class="data row2 col0" >K1</td>
#       <td id="T_096e0_row2_col1" class="data row2 col1" >K0</td>
#       <td id="T_096e0_row2_col2" class="data row2 col2" >A2</td>
#       <td id="T_096e0_row2_col3" class="data row2 col3" >B2</td>
#       <td id="T_096e0_row2_col4" class="data row2 col4" >C2</td>
#       <td id="T_096e0_row2_col5" class="data row2 col5" >D2</td>
#     </tr>
#     <tr>
#       <th id="T_096e0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_096e0_row3_col0" class="data row3 col0" >K2</td>
#       <td id="T_096e0_row3_col1" class="data row3 col1" >K0</td>
#       <td id="T_096e0_row3_col2" class="data row3 col2" >nan</td>
#       <td id="T_096e0_row3_col3" class="data row3 col3" >nan</td>
#       <td id="T_096e0_row3_col4" class="data row3 col4" >C3</td>
#       <td id="T_096e0_row3_col5" class="data row3 col5" >D3</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### INNER Merge

# %%
inner_merge = pd.merge(df1, df2, how="inner")


df1_styler = df1.style.set_table_attributes("style='display:inline'").set_caption('Left table')
df2_styler = df2.style.set_table_attributes("style='display:inline'").set_caption('Right table')
inner_merge = inner_merge.style.set_table_attributes("style='display:inline'").set_caption("inner_merge")

display_html(df1_styler._repr_html_() +  " " + df2_styler._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_9ea60" style='display:inline'>
#   <caption>Left table</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9ea60_level0_col0" class="col_heading level0 col0" >key1</th>
#       <th id="T_9ea60_level0_col1" class="col_heading level0 col1" >key2</th>
#       <th id="T_9ea60_level0_col2" class="col_heading level0 col2" >A</th>
#       <th id="T_9ea60_level0_col3" class="col_heading level0 col3" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9ea60_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9ea60_row0_col0" class="data row0 col0" >K0</td>
#       <td id="T_9ea60_row0_col1" class="data row0 col1" >K0</td>
#       <td id="T_9ea60_row0_col2" class="data row0 col2" >A0</td>
#       <td id="T_9ea60_row0_col3" class="data row0 col3" >B0</td>
#     </tr>
#     <tr>
#       <th id="T_9ea60_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9ea60_row1_col0" class="data row1 col0" >K0</td>
#       <td id="T_9ea60_row1_col1" class="data row1 col1" >K1</td>
#       <td id="T_9ea60_row1_col2" class="data row1 col2" >A1</td>
#       <td id="T_9ea60_row1_col3" class="data row1 col3" >B1</td>
#     </tr>
#     <tr>
#       <th id="T_9ea60_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9ea60_row2_col0" class="data row2 col0" >K1</td>
#       <td id="T_9ea60_row2_col1" class="data row2 col1" >K0</td>
#       <td id="T_9ea60_row2_col2" class="data row2 col2" >A2</td>
#       <td id="T_9ea60_row2_col3" class="data row2 col3" >B2</td>
#     </tr>
#     <tr>
#       <th id="T_9ea60_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9ea60_row3_col0" class="data row3 col0" >K2</td>
#       <td id="T_9ea60_row3_col1" class="data row3 col1" >K1</td>
#       <td id="T_9ea60_row3_col2" class="data row3 col2" >A3</td>
#       <td id="T_9ea60_row3_col3" class="data row3 col3" >B3</td>
#     </tr>
#   </tbody>
# </table>
#  <style type="text/css">
# </style>
# <table id="T_279f9" style='display:inline'>
#   <caption>Right table</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_279f9_level0_col0" class="col_heading level0 col0" >key1</th>
#       <th id="T_279f9_level0_col1" class="col_heading level0 col1" >key2</th>
#       <th id="T_279f9_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_279f9_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_279f9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_279f9_row0_col0" class="data row0 col0" >K0</td>
#       <td id="T_279f9_row0_col1" class="data row0 col1" >K0</td>
#       <td id="T_279f9_row0_col2" class="data row0 col2" >C0</td>
#       <td id="T_279f9_row0_col3" class="data row0 col3" >D0</td>
#     </tr>
#     <tr>
#       <th id="T_279f9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_279f9_row1_col0" class="data row1 col0" >K1</td>
#       <td id="T_279f9_row1_col1" class="data row1 col1" >K0</td>
#       <td id="T_279f9_row1_col2" class="data row1 col2" >C1</td>
#       <td id="T_279f9_row1_col3" class="data row1 col3" >D1</td>
#     </tr>
#     <tr>
#       <th id="T_279f9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_279f9_row2_col0" class="data row2 col0" >K1</td>
#       <td id="T_279f9_row2_col1" class="data row2 col1" >K0</td>
#       <td id="T_279f9_row2_col2" class="data row2 col2" >C2</td>
#       <td id="T_279f9_row2_col3" class="data row2 col3" >D2</td>
#     </tr>
#     <tr>
#       <th id="T_279f9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_279f9_row3_col0" class="data row3 col0" >K2</td>
#       <td id="T_279f9_row3_col1" class="data row3 col1" >K0</td>
#       <td id="T_279f9_row3_col2" class="data row3 col2" >C3</td>
#       <td id="T_279f9_row3_col3" class="data row3 col3" >D3</td>
#     </tr>
#   </tbody>
# </table>

# %%
display_html(inner_merge._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_acd75" style='display:inline'>
#   <caption>inner_merge</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_acd75_level0_col0" class="col_heading level0 col0" >key1</th>
#       <th id="T_acd75_level0_col1" class="col_heading level0 col1" >key2</th>
#       <th id="T_acd75_level0_col2" class="col_heading level0 col2" >A</th>
#       <th id="T_acd75_level0_col3" class="col_heading level0 col3" >B</th>
#       <th id="T_acd75_level0_col4" class="col_heading level0 col4" >C</th>
#       <th id="T_acd75_level0_col5" class="col_heading level0 col5" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_acd75_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_acd75_row0_col0" class="data row0 col0" >K0</td>
#       <td id="T_acd75_row0_col1" class="data row0 col1" >K0</td>
#       <td id="T_acd75_row0_col2" class="data row0 col2" >A0</td>
#       <td id="T_acd75_row0_col3" class="data row0 col3" >B0</td>
#       <td id="T_acd75_row0_col4" class="data row0 col4" >C0</td>
#       <td id="T_acd75_row0_col5" class="data row0 col5" >D0</td>
#     </tr>
#     <tr>
#       <th id="T_acd75_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_acd75_row1_col0" class="data row1 col0" >K1</td>
#       <td id="T_acd75_row1_col1" class="data row1 col1" >K0</td>
#       <td id="T_acd75_row1_col2" class="data row1 col2" >A2</td>
#       <td id="T_acd75_row1_col3" class="data row1 col3" >B2</td>
#       <td id="T_acd75_row1_col4" class="data row1 col4" >C1</td>
#       <td id="T_acd75_row1_col5" class="data row1 col5" >D1</td>
#     </tr>
#     <tr>
#       <th id="T_acd75_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_acd75_row2_col0" class="data row2 col0" >K1</td>
#       <td id="T_acd75_row2_col1" class="data row2 col1" >K0</td>
#       <td id="T_acd75_row2_col2" class="data row2 col2" >A2</td>
#       <td id="T_acd75_row2_col3" class="data row2 col3" >B2</td>
#       <td id="T_acd75_row2_col4" class="data row2 col4" >C2</td>
#       <td id="T_acd75_row2_col5" class="data row2 col5" >D2</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### OUTER Merge

# %%
outer_merge = pd.merge(df1, df2, how="outer")

df1_styler = df1.style.set_table_attributes("style='display:inline'").set_caption('Left table')
df2_styler = df2.style.set_table_attributes("style='display:inline'").set_caption('Right table')
outer_merge = outer_merge.style.set_table_attributes("style='display:inline'").set_caption("outer_merge")

display_html(df1_styler._repr_html_() +  " " + df2_styler._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_152a9" style='display:inline'>
#   <caption>Left table</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_152a9_level0_col0" class="col_heading level0 col0" >key1</th>
#       <th id="T_152a9_level0_col1" class="col_heading level0 col1" >key2</th>
#       <th id="T_152a9_level0_col2" class="col_heading level0 col2" >A</th>
#       <th id="T_152a9_level0_col3" class="col_heading level0 col3" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_152a9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_152a9_row0_col0" class="data row0 col0" >K0</td>
#       <td id="T_152a9_row0_col1" class="data row0 col1" >K0</td>
#       <td id="T_152a9_row0_col2" class="data row0 col2" >A0</td>
#       <td id="T_152a9_row0_col3" class="data row0 col3" >B0</td>
#     </tr>
#     <tr>
#       <th id="T_152a9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_152a9_row1_col0" class="data row1 col0" >K0</td>
#       <td id="T_152a9_row1_col1" class="data row1 col1" >K1</td>
#       <td id="T_152a9_row1_col2" class="data row1 col2" >A1</td>
#       <td id="T_152a9_row1_col3" class="data row1 col3" >B1</td>
#     </tr>
#     <tr>
#       <th id="T_152a9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_152a9_row2_col0" class="data row2 col0" >K1</td>
#       <td id="T_152a9_row2_col1" class="data row2 col1" >K0</td>
#       <td id="T_152a9_row2_col2" class="data row2 col2" >A2</td>
#       <td id="T_152a9_row2_col3" class="data row2 col3" >B2</td>
#     </tr>
#     <tr>
#       <th id="T_152a9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_152a9_row3_col0" class="data row3 col0" >K2</td>
#       <td id="T_152a9_row3_col1" class="data row3 col1" >K1</td>
#       <td id="T_152a9_row3_col2" class="data row3 col2" >A3</td>
#       <td id="T_152a9_row3_col3" class="data row3 col3" >B3</td>
#     </tr>
#   </tbody>
# </table>
#  <style type="text/css">
# </style>
# <table id="T_bfdfa" style='display:inline'>
#   <caption>Right table</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bfdfa_level0_col0" class="col_heading level0 col0" >key1</th>
#       <th id="T_bfdfa_level0_col1" class="col_heading level0 col1" >key2</th>
#       <th id="T_bfdfa_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_bfdfa_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bfdfa_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bfdfa_row0_col0" class="data row0 col0" >K0</td>
#       <td id="T_bfdfa_row0_col1" class="data row0 col1" >K0</td>
#       <td id="T_bfdfa_row0_col2" class="data row0 col2" >C0</td>
#       <td id="T_bfdfa_row0_col3" class="data row0 col3" >D0</td>
#     </tr>
#     <tr>
#       <th id="T_bfdfa_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bfdfa_row1_col0" class="data row1 col0" >K1</td>
#       <td id="T_bfdfa_row1_col1" class="data row1 col1" >K0</td>
#       <td id="T_bfdfa_row1_col2" class="data row1 col2" >C1</td>
#       <td id="T_bfdfa_row1_col3" class="data row1 col3" >D1</td>
#     </tr>
#     <tr>
#       <th id="T_bfdfa_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_bfdfa_row2_col0" class="data row2 col0" >K1</td>
#       <td id="T_bfdfa_row2_col1" class="data row2 col1" >K0</td>
#       <td id="T_bfdfa_row2_col2" class="data row2 col2" >C2</td>
#       <td id="T_bfdfa_row2_col3" class="data row2 col3" >D2</td>
#     </tr>
#     <tr>
#       <th id="T_bfdfa_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_bfdfa_row3_col0" class="data row3 col0" >K2</td>
#       <td id="T_bfdfa_row3_col1" class="data row3 col1" >K0</td>
#       <td id="T_bfdfa_row3_col2" class="data row3 col2" >C3</td>
#       <td id="T_bfdfa_row3_col3" class="data row3 col3" >D3</td>
#     </tr>
#   </tbody>
# </table>

# %%
display_html(outer_merge._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_44d55" style='display:inline'>
#   <caption>outer_merge</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_44d55_level0_col0" class="col_heading level0 col0" >key1</th>
#       <th id="T_44d55_level0_col1" class="col_heading level0 col1" >key2</th>
#       <th id="T_44d55_level0_col2" class="col_heading level0 col2" >A</th>
#       <th id="T_44d55_level0_col3" class="col_heading level0 col3" >B</th>
#       <th id="T_44d55_level0_col4" class="col_heading level0 col4" >C</th>
#       <th id="T_44d55_level0_col5" class="col_heading level0 col5" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_44d55_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_44d55_row0_col0" class="data row0 col0" >K0</td>
#       <td id="T_44d55_row0_col1" class="data row0 col1" >K0</td>
#       <td id="T_44d55_row0_col2" class="data row0 col2" >A0</td>
#       <td id="T_44d55_row0_col3" class="data row0 col3" >B0</td>
#       <td id="T_44d55_row0_col4" class="data row0 col4" >C0</td>
#       <td id="T_44d55_row0_col5" class="data row0 col5" >D0</td>
#     </tr>
#     <tr>
#       <th id="T_44d55_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_44d55_row1_col0" class="data row1 col0" >K0</td>
#       <td id="T_44d55_row1_col1" class="data row1 col1" >K1</td>
#       <td id="T_44d55_row1_col2" class="data row1 col2" >A1</td>
#       <td id="T_44d55_row1_col3" class="data row1 col3" >B1</td>
#       <td id="T_44d55_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_44d55_row1_col5" class="data row1 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_44d55_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_44d55_row2_col0" class="data row2 col0" >K1</td>
#       <td id="T_44d55_row2_col1" class="data row2 col1" >K0</td>
#       <td id="T_44d55_row2_col2" class="data row2 col2" >A2</td>
#       <td id="T_44d55_row2_col3" class="data row2 col3" >B2</td>
#       <td id="T_44d55_row2_col4" class="data row2 col4" >C1</td>
#       <td id="T_44d55_row2_col5" class="data row2 col5" >D1</td>
#     </tr>
#     <tr>
#       <th id="T_44d55_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_44d55_row3_col0" class="data row3 col0" >K1</td>
#       <td id="T_44d55_row3_col1" class="data row3 col1" >K0</td>
#       <td id="T_44d55_row3_col2" class="data row3 col2" >A2</td>
#       <td id="T_44d55_row3_col3" class="data row3 col3" >B2</td>
#       <td id="T_44d55_row3_col4" class="data row3 col4" >C2</td>
#       <td id="T_44d55_row3_col5" class="data row3 col5" >D2</td>
#     </tr>
#     <tr>
#       <th id="T_44d55_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_44d55_row4_col0" class="data row4 col0" >K2</td>
#       <td id="T_44d55_row4_col1" class="data row4 col1" >K1</td>
#       <td id="T_44d55_row4_col2" class="data row4 col2" >A3</td>
#       <td id="T_44d55_row4_col3" class="data row4 col3" >B3</td>
#       <td id="T_44d55_row4_col4" class="data row4 col4" >nan</td>
#       <td id="T_44d55_row4_col5" class="data row4 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_44d55_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_44d55_row5_col0" class="data row5 col0" >K2</td>
#       <td id="T_44d55_row5_col1" class="data row5 col1" >K0</td>
#       <td id="T_44d55_row5_col2" class="data row5 col2" >nan</td>
#       <td id="T_44d55_row5_col3" class="data row5 col3" >nan</td>
#       <td id="T_44d55_row5_col4" class="data row5 col4" >C3</td>
#       <td id="T_44d55_row5_col5" class="data row5 col5" >D3</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Merging & Concatenating in two different columns

# %%
df1_docs = pd.DataFrame({'Locations': ['Spain', 'France', 'Portugal', 'Spain'],
                    'city': ["Barcelona", "Paris", "Lisbon", "Madrid"]})
df2_docs = pd.DataFrame({'More locations': ['Spain', 'France', 'Portugal', 'Spain'],
                    'city': ["Madrid", "Lyon", "Porto", "Albacete"]})

# %%
df1_styler = df1_docs.style.set_table_attributes("style='display:inline'").set_caption('Left table')
df2_styler = df2_docs.style.set_table_attributes("style='display:inline'").set_caption('Right table')

display_html(df1_styler._repr_html_() +  " " + df2_styler._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_e115f" style='display:inline'>
#   <caption>Left table</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e115f_level0_col0" class="col_heading level0 col0" >Locations</th>
#       <th id="T_e115f_level0_col1" class="col_heading level0 col1" >city</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e115f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e115f_row0_col0" class="data row0 col0" >Spain</td>
#       <td id="T_e115f_row0_col1" class="data row0 col1" >Barcelona</td>
#     </tr>
#     <tr>
#       <th id="T_e115f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e115f_row1_col0" class="data row1 col0" >France</td>
#       <td id="T_e115f_row1_col1" class="data row1 col1" >Paris</td>
#     </tr>
#     <tr>
#       <th id="T_e115f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e115f_row2_col0" class="data row2 col0" >Portugal</td>
#       <td id="T_e115f_row2_col1" class="data row2 col1" >Lisbon</td>
#     </tr>
#     <tr>
#       <th id="T_e115f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e115f_row3_col0" class="data row3 col0" >Spain</td>
#       <td id="T_e115f_row3_col1" class="data row3 col1" >Madrid</td>
#     </tr>
#   </tbody>
# </table>
#  <style type="text/css">
# </style>
# <table id="T_c990a" style='display:inline'>
#   <caption>Right table</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c990a_level0_col0" class="col_heading level0 col0" >More locations</th>
#       <th id="T_c990a_level0_col1" class="col_heading level0 col1" >city</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c990a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c990a_row0_col0" class="data row0 col0" >Spain</td>
#       <td id="T_c990a_row0_col1" class="data row0 col1" >Madrid</td>
#     </tr>
#     <tr>
#       <th id="T_c990a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c990a_row1_col0" class="data row1 col0" >France</td>
#       <td id="T_c990a_row1_col1" class="data row1 col1" >Lyon</td>
#     </tr>
#     <tr>
#       <th id="T_c990a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c990a_row2_col0" class="data row2 col0" >Portugal</td>
#       <td id="T_c990a_row2_col1" class="data row2 col1" >Porto</td>
#     </tr>
#     <tr>
#       <th id="T_c990a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c990a_row3_col0" class="data row3 col0" >Spain</td>
#       <td id="T_c990a_row3_col1" class="data row3 col1" >Albacete</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Concatenating in two different columns

# %%
concat_docs = pd.concat([df1_docs, df2_docs], axis=1, keys=["1st table", "2nd table"])

df1_styler = df1_docs.style.set_table_attributes("style='display:inline'").set_caption('Left table')
df2_styler = df2_docs.style.set_table_attributes("style='display:inline'").set_caption('Right table')
merge_styler = concat_docs.style.set_table_attributes("style='display:inline'").set_caption('concat_docs')

display_html(df1_styler._repr_html_() +  " " + df2_styler._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_333b0" style='display:inline'>
#   <caption>Left table</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_333b0_level0_col0" class="col_heading level0 col0" >Locations</th>
#       <th id="T_333b0_level0_col1" class="col_heading level0 col1" >city</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_333b0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_333b0_row0_col0" class="data row0 col0" >Spain</td>
#       <td id="T_333b0_row0_col1" class="data row0 col1" >Barcelona</td>
#     </tr>
#     <tr>
#       <th id="T_333b0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_333b0_row1_col0" class="data row1 col0" >France</td>
#       <td id="T_333b0_row1_col1" class="data row1 col1" >Paris</td>
#     </tr>
#     <tr>
#       <th id="T_333b0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_333b0_row2_col0" class="data row2 col0" >Portugal</td>
#       <td id="T_333b0_row2_col1" class="data row2 col1" >Lisbon</td>
#     </tr>
#     <tr>
#       <th id="T_333b0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_333b0_row3_col0" class="data row3 col0" >Spain</td>
#       <td id="T_333b0_row3_col1" class="data row3 col1" >Madrid</td>
#     </tr>
#   </tbody>
# </table>
#  <style type="text/css">
# </style>
# <table id="T_9fa6c" style='display:inline'>
#   <caption>Right table</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9fa6c_level0_col0" class="col_heading level0 col0" >More locations</th>
#       <th id="T_9fa6c_level0_col1" class="col_heading level0 col1" >city</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9fa6c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9fa6c_row0_col0" class="data row0 col0" >Spain</td>
#       <td id="T_9fa6c_row0_col1" class="data row0 col1" >Madrid</td>
#     </tr>
#     <tr>
#       <th id="T_9fa6c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9fa6c_row1_col0" class="data row1 col0" >France</td>
#       <td id="T_9fa6c_row1_col1" class="data row1 col1" >Lyon</td>
#     </tr>
#     <tr>
#       <th id="T_9fa6c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9fa6c_row2_col0" class="data row2 col0" >Portugal</td>
#       <td id="T_9fa6c_row2_col1" class="data row2 col1" >Porto</td>
#     </tr>
#     <tr>
#       <th id="T_9fa6c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9fa6c_row3_col0" class="data row3 col0" >Spain</td>
#       <td id="T_9fa6c_row3_col1" class="data row3 col1" >Albacete</td>
#     </tr>
#   </tbody>
# </table>

# %%
display_html(merge_styler._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_6c6c9" style='display:inline'>
#   <caption>concat_docs</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6c6c9_level0_col0" class="col_heading level0 col0" colspan="2">1st table</th>
#       <th id="T_6c6c9_level0_col2" class="col_heading level0 col2" colspan="2">2nd table</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_6c6c9_level1_col0" class="col_heading level1 col0" >Locations</th>
#       <th id="T_6c6c9_level1_col1" class="col_heading level1 col1" >city</th>
#       <th id="T_6c6c9_level1_col2" class="col_heading level1 col2" >More locations</th>
#       <th id="T_6c6c9_level1_col3" class="col_heading level1 col3" >city</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6c6c9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6c6c9_row0_col0" class="data row0 col0" >Spain</td>
#       <td id="T_6c6c9_row0_col1" class="data row0 col1" >Barcelona</td>
#       <td id="T_6c6c9_row0_col2" class="data row0 col2" >Spain</td>
#       <td id="T_6c6c9_row0_col3" class="data row0 col3" >Madrid</td>
#     </tr>
#     <tr>
#       <th id="T_6c6c9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6c6c9_row1_col0" class="data row1 col0" >France</td>
#       <td id="T_6c6c9_row1_col1" class="data row1 col1" >Paris</td>
#       <td id="T_6c6c9_row1_col2" class="data row1 col2" >France</td>
#       <td id="T_6c6c9_row1_col3" class="data row1 col3" >Lyon</td>
#     </tr>
#     <tr>
#       <th id="T_6c6c9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6c6c9_row2_col0" class="data row2 col0" >Portugal</td>
#       <td id="T_6c6c9_row2_col1" class="data row2 col1" >Lisbon</td>
#       <td id="T_6c6c9_row2_col2" class="data row2 col2" >Portugal</td>
#       <td id="T_6c6c9_row2_col3" class="data row2 col3" >Porto</td>
#     </tr>
#     <tr>
#       <th id="T_6c6c9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6c6c9_row3_col0" class="data row3 col0" >Spain</td>
#       <td id="T_6c6c9_row3_col1" class="data row3 col1" >Madrid</td>
#       <td id="T_6c6c9_row3_col2" class="data row3 col2" >Spain</td>
#       <td id="T_6c6c9_row3_col3" class="data row3 col3" >Albacete</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Merging in two different columns

# %%
df1_styler = df1_docs.style.set_table_attributes("style='display:inline'").set_caption('Left table')
df2_styler = df2_docs.style.set_table_attributes("style='display:inline'").set_caption('Right table')

display_html(df1_styler._repr_html_() +  " " + df2_styler._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_70bd3" style='display:inline'>
#   <caption>Left table</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_70bd3_level0_col0" class="col_heading level0 col0" >Locations</th>
#       <th id="T_70bd3_level0_col1" class="col_heading level0 col1" >city</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_70bd3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_70bd3_row0_col0" class="data row0 col0" >Spain</td>
#       <td id="T_70bd3_row0_col1" class="data row0 col1" >Barcelona</td>
#     </tr>
#     <tr>
#       <th id="T_70bd3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_70bd3_row1_col0" class="data row1 col0" >France</td>
#       <td id="T_70bd3_row1_col1" class="data row1 col1" >Paris</td>
#     </tr>
#     <tr>
#       <th id="T_70bd3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_70bd3_row2_col0" class="data row2 col0" >Portugal</td>
#       <td id="T_70bd3_row2_col1" class="data row2 col1" >Lisbon</td>
#     </tr>
#     <tr>
#       <th id="T_70bd3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_70bd3_row3_col0" class="data row3 col0" >Spain</td>
#       <td id="T_70bd3_row3_col1" class="data row3 col1" >Madrid</td>
#     </tr>
#   </tbody>
# </table>
#  <style type="text/css">
# </style>
# <table id="T_cf313" style='display:inline'>
#   <caption>Right table</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cf313_level0_col0" class="col_heading level0 col0" >More locations</th>
#       <th id="T_cf313_level0_col1" class="col_heading level0 col1" >city</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cf313_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cf313_row0_col0" class="data row0 col0" >Spain</td>
#       <td id="T_cf313_row0_col1" class="data row0 col1" >Madrid</td>
#     </tr>
#     <tr>
#       <th id="T_cf313_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cf313_row1_col0" class="data row1 col0" >France</td>
#       <td id="T_cf313_row1_col1" class="data row1 col1" >Lyon</td>
#     </tr>
#     <tr>
#       <th id="T_cf313_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cf313_row2_col0" class="data row2 col0" >Portugal</td>
#       <td id="T_cf313_row2_col1" class="data row2 col1" >Porto</td>
#     </tr>
#     <tr>
#       <th id="T_cf313_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cf313_row3_col0" class="data row3 col0" >Spain</td>
#       <td id="T_cf313_row3_col1" class="data row3 col1" >Albacete</td>
#     </tr>
#   </tbody>
# </table>

# %%
merge_docs = df1_docs.merge(df2_docs, left_on='Locations', right_on='More locations', suffixes = ["_fromlastyear", "_fromthisyear"])

# %%
merge_docs = df1_docs.merge(df2_docs,  left_on='Locations', right_on='More locations', suffixes = ["_fromleft", "_fromright"])


df1_styler = df1_docs.style.set_table_attributes("style='display:inline'").set_caption('Left table')
df2_styler = df2_docs.style.set_table_attributes("style='display:inline'").set_caption('Right table')
merge_styler = merge_docs.style.set_table_attributes("style='display:inline'").set_caption('merge_docs')

display_html(df1_styler._repr_html_() + " " + df2_styler._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_4adc6" style='display:inline'>
#   <caption>Left table</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4adc6_level0_col0" class="col_heading level0 col0" >Locations</th>
#       <th id="T_4adc6_level0_col1" class="col_heading level0 col1" >city</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4adc6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4adc6_row0_col0" class="data row0 col0" >Spain</td>
#       <td id="T_4adc6_row0_col1" class="data row0 col1" >Barcelona</td>
#     </tr>
#     <tr>
#       <th id="T_4adc6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4adc6_row1_col0" class="data row1 col0" >France</td>
#       <td id="T_4adc6_row1_col1" class="data row1 col1" >Paris</td>
#     </tr>
#     <tr>
#       <th id="T_4adc6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4adc6_row2_col0" class="data row2 col0" >Portugal</td>
#       <td id="T_4adc6_row2_col1" class="data row2 col1" >Lisbon</td>
#     </tr>
#     <tr>
#       <th id="T_4adc6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4adc6_row3_col0" class="data row3 col0" >Spain</td>
#       <td id="T_4adc6_row3_col1" class="data row3 col1" >Madrid</td>
#     </tr>
#   </tbody>
# </table>
#  <style type="text/css">
# </style>
# <table id="T_fc6e0" style='display:inline'>
#   <caption>Right table</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fc6e0_level0_col0" class="col_heading level0 col0" >More locations</th>
#       <th id="T_fc6e0_level0_col1" class="col_heading level0 col1" >city</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fc6e0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fc6e0_row0_col0" class="data row0 col0" >Spain</td>
#       <td id="T_fc6e0_row0_col1" class="data row0 col1" >Madrid</td>
#     </tr>
#     <tr>
#       <th id="T_fc6e0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fc6e0_row1_col0" class="data row1 col0" >France</td>
#       <td id="T_fc6e0_row1_col1" class="data row1 col1" >Lyon</td>
#     </tr>
#     <tr>
#       <th id="T_fc6e0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fc6e0_row2_col0" class="data row2 col0" >Portugal</td>
#       <td id="T_fc6e0_row2_col1" class="data row2 col1" >Porto</td>
#     </tr>
#     <tr>
#       <th id="T_fc6e0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fc6e0_row3_col0" class="data row3 col0" >Spain</td>
#       <td id="T_fc6e0_row3_col1" class="data row3 col1" >Albacete</td>
#     </tr>
#   </tbody>
# </table>

# %%
display_html(merge_styler._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_55606" style='display:inline'>
#   <caption>merge_docs</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_55606_level0_col0" class="col_heading level0 col0" >Locations</th>
#       <th id="T_55606_level0_col1" class="col_heading level0 col1" >city_fromleft</th>
#       <th id="T_55606_level0_col2" class="col_heading level0 col2" >More locations</th>
#       <th id="T_55606_level0_col3" class="col_heading level0 col3" >city_fromright</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_55606_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_55606_row0_col0" class="data row0 col0" >Spain</td>
#       <td id="T_55606_row0_col1" class="data row0 col1" >Barcelona</td>
#       <td id="T_55606_row0_col2" class="data row0 col2" >Spain</td>
#       <td id="T_55606_row0_col3" class="data row0 col3" >Madrid</td>
#     </tr>
#     <tr>
#       <th id="T_55606_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_55606_row1_col0" class="data row1 col0" >Spain</td>
#       <td id="T_55606_row1_col1" class="data row1 col1" >Barcelona</td>
#       <td id="T_55606_row1_col2" class="data row1 col2" >Spain</td>
#       <td id="T_55606_row1_col3" class="data row1 col3" >Albacete</td>
#     </tr>
#     <tr>
#       <th id="T_55606_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_55606_row2_col0" class="data row2 col0" >Spain</td>
#       <td id="T_55606_row2_col1" class="data row2 col1" >Madrid</td>
#       <td id="T_55606_row2_col2" class="data row2 col2" >Spain</td>
#       <td id="T_55606_row2_col3" class="data row2 col3" >Madrid</td>
#     </tr>
#     <tr>
#       <th id="T_55606_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_55606_row3_col0" class="data row3 col0" >Spain</td>
#       <td id="T_55606_row3_col1" class="data row3 col1" >Madrid</td>
#       <td id="T_55606_row3_col2" class="data row3 col2" >Spain</td>
#       <td id="T_55606_row3_col3" class="data row3 col3" >Albacete</td>
#     </tr>
#     <tr>
#       <th id="T_55606_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_55606_row4_col0" class="data row4 col0" >France</td>
#       <td id="T_55606_row4_col1" class="data row4 col1" >Paris</td>
#       <td id="T_55606_row4_col2" class="data row4 col2" >France</td>
#       <td id="T_55606_row4_col3" class="data row4 col3" >Lyon</td>
#     </tr>
#     <tr>
#       <th id="T_55606_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_55606_row5_col0" class="data row5 col0" >Portugal</td>
#       <td id="T_55606_row5_col1" class="data row5 col1" >Lisbon</td>
#       <td id="T_55606_row5_col2" class="data row5 col2" >Portugal</td>
#       <td id="T_55606_row5_col3" class="data row5 col3" >Porto</td>
#     </tr>
#   </tbody>
# </table>

# %%
# suffixes: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.merge.html

# %%
# concat: putting things together
# join/merge: putting things together THAT ARE RELATED
    # related info in the same place -> reduces redundancy

# %%
# ON PANDAS! 
    # merge
        # a common column
    # join
        # on the index

# %% [markdown]
# ### Join: relating index
# The join, unlike the merge, will join the dataframes and where there are no records in the "index" it will put NaN

# %%
import numpy as np
import pandas as pd   
from IPython.display import display_html

# %%
left_df = pd.DataFrame(
    {"A": ["A0", "A1", "A2"], "B": ["B0", "B1", "B2"]}, index=["K0", "K1", "K2"]
)


right_df = pd.DataFrame(
    {"C": ["C0", "C2", "C3"], "D": ["D0", "D2", "D3"]}, index=["K0", "K2", "K3"]
)

# %%
df1_styler = left_df.style.set_table_attributes("style='display:inline'").set_caption('Left table')
df2_styler = right_df.style.set_table_attributes("style='display:inline'").set_caption('Right table')

display_html(df1_styler._repr_html_()+ df2_styler._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_8f64f" style='display:inline'>
#   <caption>Left table</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8f64f_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_8f64f_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8f64f_level0_row0" class="row_heading level0 row0" >K0</th>
#       <td id="T_8f64f_row0_col0" class="data row0 col0" >A0</td>
#       <td id="T_8f64f_row0_col1" class="data row0 col1" >B0</td>
#     </tr>
#     <tr>
#       <th id="T_8f64f_level0_row1" class="row_heading level0 row1" >K1</th>
#       <td id="T_8f64f_row1_col0" class="data row1 col0" >A1</td>
#       <td id="T_8f64f_row1_col1" class="data row1 col1" >B1</td>
#     </tr>
#     <tr>
#       <th id="T_8f64f_level0_row2" class="row_heading level0 row2" >K2</th>
#       <td id="T_8f64f_row2_col0" class="data row2 col0" >A2</td>
#       <td id="T_8f64f_row2_col1" class="data row2 col1" >B2</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_78244" style='display:inline'>
#   <caption>Right table</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_78244_level0_col0" class="col_heading level0 col0" >C</th>
#       <th id="T_78244_level0_col1" class="col_heading level0 col1" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_78244_level0_row0" class="row_heading level0 row0" >K0</th>
#       <td id="T_78244_row0_col0" class="data row0 col0" >C0</td>
#       <td id="T_78244_row0_col1" class="data row0 col1" >D0</td>
#     </tr>
#     <tr>
#       <th id="T_78244_level0_row1" class="row_heading level0 row1" >K2</th>
#       <td id="T_78244_row1_col0" class="data row1 col0" >C2</td>
#       <td id="T_78244_row1_col1" class="data row1 col1" >D2</td>
#     </tr>
#     <tr>
#       <th id="T_78244_level0_row2" class="row_heading level0 row2" >K3</th>
#       <td id="T_78244_row2_col0" class="data row2 col0" >C3</td>
#       <td id="T_78244_row2_col1" class="data row2 col1" >D3</td>
#     </tr>
#   </tbody>
# </table>

# %%
result = left_df.join(right_df, how="inner")

#Rendering the df's in the same line. No need to learn this code

df1_styler = left_df.style.set_table_attributes("style='display:inline'").set_caption('Left table')
df2_styler = right_df.style.set_table_attributes("style='display:inline'").set_caption('Right table')
df1_df2_merged = result.style.set_table_attributes("style='display:inline'").set_caption('JOIN')

display_html(df1_styler._repr_html_()+ df2_styler._repr_html_() + df1_df2_merged._repr_html_(), raw=True)
#display_html(df1_styler._repr_html_()+ df2_styler._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_90200" style='display:inline'>
#   <caption>Left table</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_90200_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_90200_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_90200_level0_row0" class="row_heading level0 row0" >K0</th>
#       <td id="T_90200_row0_col0" class="data row0 col0" >A0</td>
#       <td id="T_90200_row0_col1" class="data row0 col1" >B0</td>
#     </tr>
#     <tr>
#       <th id="T_90200_level0_row1" class="row_heading level0 row1" >K1</th>
#       <td id="T_90200_row1_col0" class="data row1 col0" >A1</td>
#       <td id="T_90200_row1_col1" class="data row1 col1" >B1</td>
#     </tr>
#     <tr>
#       <th id="T_90200_level0_row2" class="row_heading level0 row2" >K2</th>
#       <td id="T_90200_row2_col0" class="data row2 col0" >A2</td>
#       <td id="T_90200_row2_col1" class="data row2 col1" >B2</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_ba21d" style='display:inline'>
#   <caption>Right table</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ba21d_level0_col0" class="col_heading level0 col0" >C</th>
#       <th id="T_ba21d_level0_col1" class="col_heading level0 col1" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ba21d_level0_row0" class="row_heading level0 row0" >K0</th>
#       <td id="T_ba21d_row0_col0" class="data row0 col0" >C0</td>
#       <td id="T_ba21d_row0_col1" class="data row0 col1" >D0</td>
#     </tr>
#     <tr>
#       <th id="T_ba21d_level0_row1" class="row_heading level0 row1" >K2</th>
#       <td id="T_ba21d_row1_col0" class="data row1 col0" >C2</td>
#       <td id="T_ba21d_row1_col1" class="data row1 col1" >D2</td>
#     </tr>
#     <tr>
#       <th id="T_ba21d_level0_row2" class="row_heading level0 row2" >K3</th>
#       <td id="T_ba21d_row2_col0" class="data row2 col0" >C3</td>
#       <td id="T_ba21d_row2_col1" class="data row2 col1" >D3</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_eaf97" style='display:inline'>
#   <caption>JOIN</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eaf97_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_eaf97_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_eaf97_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_eaf97_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eaf97_level0_row0" class="row_heading level0 row0" >K0</th>
#       <td id="T_eaf97_row0_col0" class="data row0 col0" >A0</td>
#       <td id="T_eaf97_row0_col1" class="data row0 col1" >B0</td>
#       <td id="T_eaf97_row0_col2" class="data row0 col2" >C0</td>
#       <td id="T_eaf97_row0_col3" class="data row0 col3" >D0</td>
#     </tr>
#     <tr>
#       <th id="T_eaf97_level0_row1" class="row_heading level0 row1" >K2</th>
#       <td id="T_eaf97_row1_col0" class="data row1 col0" >A2</td>
#       <td id="T_eaf97_row1_col1" class="data row1 col1" >B2</td>
#       <td id="T_eaf97_row1_col2" class="data row1 col2" >C2</td>
#       <td id="T_eaf97_row1_col3" class="data row1 col3" >D2</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Differences between join & merge

# %% [markdown]
# <figure class="wp-block-table is-style-stripes"><table class="has-fixed-layout"><thead><tr><th><strong>Join Feature</strong></th><th class="has-text-align-center" data-align="center"><strong>join()</strong></th><th class="has-text-align-center" data-align="center"><strong>merge()</strong></th></tr></thead><tbody><tr><td>inner</td><td class="has-text-align-center" data-align="center">Yes</td><td class="has-text-align-center" data-align="center">Yes</td></tr><tr><td>left</td><td class="has-text-align-center" data-align="center">Yes</td><td class="has-text-align-center" data-align="center">Yes</td></tr><tr><td>right</td><td class="has-text-align-center" data-align="center">Yes</td><td class="has-text-align-center" data-align="center">Yes</td></tr><tr><td>outer</td><td class="has-text-align-center" data-align="center">Yes</td><td class="has-text-align-center" data-align="center">Yes</td></tr><tr><td>cross</td><td class="has-text-align-center" data-align="center">X</td><td class="has-text-align-center" data-align="center">Yes</td></tr><tr><td>Join on Indices</td><td class="has-text-align-center" data-align="center">Yes</td><td class="has-text-align-center" data-align="center">Yes</td></tr><tr><td>Join on Columns</td><td class="has-text-align-center" data-align="center">X</td><td class="has-text-align-center" data-align="center">Yes</td></tr><tr><td>Left on column, right on index</td><td class="has-text-align-center" data-align="center">Yes</td><td class="has-text-align-center" data-align="center">Yes</td></tr><tr><td>Left on index, right on column</td><td class="has-text-align-center" data-align="center">X</td><td class="has-text-align-center" data-align="center">Yes</td></tr></tbody></table>

# %% [markdown]
# # RECAP

# %% [markdown]
# - subsets
#     - `df[[col1, col2]]`
#
# - aggregations
#     - groupby
#         - `df[[col1, col2]].groupby(CATEOGORICAL).agg({QUANTITAVE_1: "mean", QUANTITAVE_2: "max"})`
#         - `df[[col1, col2]].groupby(CATEOGORICAL).mean()`
#         - count, mean, max, min, median, std,...
#
#     - pivot_table
#         - same: other syntax
#         - `df.pivot_table(values="MonthlyIncome", index="Department", aggfunc="mean")`
#
#     - crosstab
#         - pd.crosstab: default count
#             - aggfunc = "mean"
#             - make sure you have selected quantitative vars
#
# - JOINS & MERGE & CONCAT
#
#     - Put together: phisically (not relation-ally)
#         - side to side: concat on axis=1
#             - if you don't share columns(?). diagonal? same as outer-merge?
#
#              common_key A B    | common_key C D -> merge based on common_key
#
#
#
#                A B |   C D -> CONCAT(on axis=1):
#             1 10 10  Nan Nan
#             2 10 10  Nan Nan
#             3 Nan Nan 20 20
#             4 Nan Nan 20 20
#
#
#         - top & bottom: concat on axis = 0 (appending rows)
#             - if share columns
#
#     - MERGE & JOIN (pandas)
#         - merge on pandas: putting tables together based on a common COLUMN
#         - join on pandas: putting tables together based on the INDEX
#
#
#         -  _on SQL join is columns_

# %%
# 1. What I want to see (salary)
# 2. Based on what

# 3. How specifically

# %% [markdown]
# ```
# df = pd.DataFrame(object) # classes
# df.drop() #methods
# df["sdsddsd"] = df["sdsdsd"].apply(lambda x: x.upper()) # lambda
# df["sdsddsd"] = df["sdsdsd"].apply(user_defined_function) # functions
# df[df["dfdf"] == 10] #numpy
# df["col"] = df["col"].apply() # map (loop & function)
# df.dtypes #-> floats, int, str,.... # data types
# ```

# %% [markdown]
# ## Pandas usual methods
# ```python
# df.head() # prints the head, default 5 rows
# df.tail() # set the tail, default 5 rows
# df.describe() # statistical description
# df.info() # df information
# df.columns # show column
# df.index # show index
# df.dtypes # show column data types
# df.plot() # make a plot
# df.hist() # make a histogram
# df.col.value_counts() # counts the unique values ​​of a column
# df.col.unique() # returns unique values ​​from a column
# df.copy() # copies the df
# df.drop() # remove columns or rows (axis=0,1)
# df.dropna() # remove nulls
# df.fillna() # fills nulls
# df.shape # dimensions of the df
# df._get_numeric_data() # select numeric columns
# df.rename() # rename columns
# df.str.replace() # replace columns of strings
# df.astype(dtype='float32') # change the data type
# df.iloc[] # locate by index
# df.loc[] # locate by element
# df.transpose() # transposes the df
# df.T
# df.sample(n, frac) # sample from df
# df.col.sum() # sum of a column
# df.col.max() # maximum of a column
# df.col.min() # minimum of one column
# df[col] # select column
# df.col
# df.isnull() # null values
# df.isna()
# df.notna() # not null values
# df.drop_duplicates() # remove duplicates
# df.reset_index(inplace=True) # reset the index and overwrite
# ```

# %% [markdown]
# ## Further materials
#
# * [Read the docs!](https://pandas.pydata.org/pandas-docs/stable/index.html)
# * [Cheatsheet](https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf)
# * [Exercises to practice](https://github.com/guipsamora/pandas_exercises)
# * [More on merge, concat, and join](https://realpython.com/pandas-merge-join-and-concat/#pandas-join-combining-data-on-a-column-or-index). And [even more!](https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html)
