# %%
import pandas as pd
import numpy as np

# Set the number of rows in the dataframe
num_rows = 1000

# Create a dictionary of random data
data_dict = {
    'student_id': np.random.randint(10000, 99999, size=num_rows),
    'grade': np.random.randint(0, 101, size=num_rows),
    'subject_id': np.random.randint(0, 11, size=num_rows)
}

# Create the dataframe from the dictionary
df = pd.DataFrame(data_dict)

# Print the dataframe
df.to_csv("grades.csv", index=False)

# %% [markdown]
# - SQL through python: sqlalchemy
#     - regex
#     - calculations of dates
#     - case when
#     - Re-using code
#         - procedures
#         - views
#         - temp tables
#
#     - subqueries
#         - nested query
#         - many
#         - "join" tables through subqueries
#         - Join vs. subquery:
#             - join if you're selecting more things from the table
#             - subquery: as a condition
#     - joins
#         - self
#         - cross
#         - full join
#         - left & right
#         - inner (default in MySQL)
#     - postgresql: quotes are single
#
#
# - mongodb
# - inserting db into mongo
#     - insert infom from API to mongoDB
#
# - relational vs. noSQL
#     - organized vs not organized
#         - tables vs documents
#         - primary keys & foreign keys
#             - father -> children
#             - UNIQUE
#             - One PK per table
#             - FK: as many as you want
#                 - Needs to be a PK somewhere else
#             - FK: repeated or unique?
#                 - values can be repeated when it's a FK
#                 - Not repeated in the original table
#
# - visualizations
#     - folium maps
#     - carto maps
#     - HeatMaps
#     - Regular maps with pins
#     - objects
#         - Map
#         - Icon
#         - Marker
#         - HeatMap
#
#
# - geo info
#     - lat, lon
#     - POINT(lat, lon)
#
# - `.env`
#     - 1. Create the .env file (touch on bash or through VSC)
#     - 2. Create .gitignore
#     - 3. Save variable into .env file (var="value")
#     - 4. Write `.env` within `.gitignore`
#     - 5. Load it back: `load_dotenv()`
#     - 6. variable = os.getenv("var")
#     - 6. variable = os.getenv("CLIENT_ID")
#     - 6. variable = os.getenv("CLIENT_SECRET")
#     - 7. If print: DELETE
#
# - READ THE DOCS
