# %% [markdown]
# # RECAP - week 3
#
# - git
#     - what
#         - "Facebook for code" (github)
#         - version control (VCS)
#             - keep track of changes
#             - go back in time and fix issues
#             - code can break with simple things
#     - why
#         - create collaborative projects
#         - contribute someone else's code
#     - how
#         - pull: take ONLY the updates (commits you're missing)
#         - clone: donwload the whole thing
#         - fork: copy and make it yours. a copy under your name
#         - push: update your version/your new commits to the cloud: to the remote
#         - pull request: asking someone to include your changes (pull from your repo)
#         - merge: combining two repos
#         - stash: saving without reaching the commit part
#         - branches: main/master, others
#             - different versions
#                 - commits: across time
#                 - branches: cross "universes"
#             - PARALLEL versions (development, deployment,..)
#
#
# - Bash: language
#     - navigating the computer through terminal
#
# ### ORGANIZATION OF CODE
# - modularization (import yuour own modules)
# - encapsulation
# - error handling
#
#
# ### Python
# - functions
#     - what:
#         - "expression, does things, arguments"
#         - return or no return
#         - def funct -> return OR None
#             - "a function returns None"
#                 def function ():
#                     os.system("say hello")
#
#     - three types
#           - built-in: print("Hello") / str_.upper()
#           - user-defined: def greetings
#           - lambda: lambda x: x*2
#
#     - why
#         - re-usability
#             - some parts & variable parts (args)
#         - debug
#             - main.py
#                 - cleaning.py
#                     - def rename_columns ()
#                         - keyError: renaming a column that doesn't exist?
#         - abstraction
#             - make them lesss complex
#                 - how many of lines of code
#                 - the bult-in methods
#                 - external functions
#                 ...
#                 - cleaning.rename_columns(df)
#                 - pandas.read_csv("path")
#     - how
#         - define
#             - args
#         - call
#
#
# - OOP: object oriented programming
#     - paradigm / approach (way to do things)
#     - goal: re-use the code
#     - class ChocolateCookie ():
#         def __init__ (self, NAME):
#             self.NAME = NAME
#             self.flavor = "chocolate"
#
#             def GREETINGS (methods):
#                 pass
#
#     - Methods & attributes
#     - Instance vs class
#         - class is: cookie-cutter
#         - instance: cookie you bake
#     - Inheritance
#         - class to another class (drag the elements)
#
# - Comprehension lists
#     - one-liner: create/modify a list
#     - cleaner & easier to read(?) & way faster
#     - no appending needed & no need to create a list from scratch
#
# - lambda
#     - a FUNCTION we use once
#     - no need to define: quick & easy
#
# - regex
#
#
# ### Libraries
#
# - numpy
#     - arrays
# - pandas
#     - dataframes
#
# ### visualization
#
# - matplotlib
# - seaborn
# - plotly - extra

# %% [markdown]
# # DATA ANALYSIS PROCESSES
#
# - EDA
#     - exploratory
#     - data
#     - analysis
#
# - ETL: extraction-transformation-loading
#     - Extraction
#         - APIs
#         - web-scrapping
#         - DDBB: relational & non-relational
#
#      - Transformation
#          - Python: pandas
#
#      - Loading
#          - DDBB
#
# - Visualize
#
# - Patterns in the data: models
#     - summarize the info
#     - predict information (machine learning :) )
