# %% [markdown]
# - 1. Extract information
#     - APIs
#     - Web-scrapping
#     - DB
#
# - 2. Transform data
#     - Python: pandas
#
# - 3. Describe data
#     - Statistics
#
# - 4. Visualize
#     - Python: seaborn, matplotlib, plotly, folium
#     - Tableau
#
# - 5. Load the info into databases
#     - MySQL
#     - MongoDB
#
# - 6. Models of the data: predictions
#     - Python

# %% [markdown]
# - Bash
# - Git & github
#
# - PYTHON
#     - Data types
#     - Data structures
#     - Flow control
#         - For loops
#         - while loops
#         - if/elif/else
#      - Error handling
#      - Map, filter, reduce
#      - Functions
#         - user-defined
#         - built-in
#         - lambda
#      - Comprehension lists
#      - OOP: object oriented programming
#      - Meta-code: Pseudocode, refactoring, following PEP-8 guidelines
#
#
#     - Pandas
#     - Numpy
#
# - Visualization
#      - Seaborn
#      - Matplotlib
#      - Plotly
#      - Folium & Carto
#
# - APIs
#     - 4square
#
# - Web scrapping
#
# - SQL
#     - Queries & subqueries
#     - Joins
#     - Groupby, concat
#     - Views
#     - Temporary tables
#     - Procedures
#     - Connect through python: sqlalchemy
#     - CRUD: Create, Read, Update, Delete
#
# - MongoDB
#     - CRUD: Create, Read, Update, Delete
#
#
# - Statistics & probability
#     - p_value
#     - t-test
#     - Binomial
#     - Hypotheses
#
#     - Distributions
#         - 1. Central tendency
#             - Mean, mode, median
#         - 2. Dispersion
#             - Variance
#             - Standard deviation
#         - 3. Skewness: side-to-side
#         - 4. Kurtosis: bottom-up
#
#     - Two variables
#         - Covariance
#         - Correlation
#
#     - Visualize
#         - One distribution
#             - Histplot: continuous
#             - Barplot: categorical
#             - Boxplot
#                 - Median
#                 - Outliers
#                 - Quartiles
#                 - Size of the box: 50% closest to the median
#                 - Whiskers:
#                     - If outliers: "max" / threshold / 1.5 IQR + Q3
#                     - If not outliers: max.
#
#
#         - Two distributions
#             - Scatterplot
#             - Heatmap
#             - Pairplot

# %%
"""
p_value: 
    probability of getting that result
    knowing/assuming H0 is true
    
    How likely was this result?
    
    P(something | H0)
    
    alpha=0.05, leven of significance
"""
# Out:
# '\np_value: \n    probability of getting that result\n    knowing/assuming H0 is true\n    \n    How likely was this result?\n    \n    P(something |\xa0H0)\n    \n    alpha=0.05, leven of significance\n'
